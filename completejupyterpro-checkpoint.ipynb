# %% [markdown]
# ### VANDERPUYE MUBARAK
# ### 10984477
# ### MATERIALS SCIENCE AND ENGINEERING
# ### PROJECT 1

# %%
import pandas as pd

# %%
dataset = pd.read_csv('C:/Users/xvole/Desktop/BOOKS/Data.csv')

# %%
dataset
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
new_dataset = dataset.dropna()

# %%
new_dataset
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
mean_fixed_acidity = new_dataset.fixed_acidity.mean()
mean_volatile_acidity = new_dataset.volatile_acidity.mean()
mean_citric_acid = new_dataset.citric_acid.mean()
mean_residual_sugar = new_dataset.residual_sugar.mean()
mean_chlorides = new_dataset.chlorides.mean()
mean_free_sulfur_dioxide = new_dataset.free_sulfur_dioxide.mean()
mean_total_sulfur_dioxide = new_dataset.total_sulfur_dioxide.mean()
mean_density = new_dataset.density.mean()
mean_pH = new_dataset.pH.mean()
mean_sulphates = new_dataset.sulphates.mean()
mean_alcohol = new_dataset.alcohol.mean()
mean_quality = new_dataset.quality.mean()

# %%
print(f'fixed_acidity:{mean_fixed_acidity }')
print(f'volatile_acidity:{mean_volatile_acidity}')
print(f'citric_acid:{mean_citric_acid}')
print(f'residual_sugar:{mean_residual_sugar}')
print(f'chlorides:{mean_chlorides }')
print(f'free_sulfur_dioxide:{mean_free_sulfur_dioxide}')
print(f'total_sulfur_dioxide:{mean_total_sulfur_dioxide}')
print(f'density:{mean_density}')
print(f'pH:{mean_pH}')
print(f'sulphates:{mean_sulphates}')
print(f'alcohol:{mean_alcohol}')
print(f'quality:{mean_quality}')
# Out:
# fixed_acidity:8.32061596480201
# volatile_acidity:0.5276807039597737
# citric_acid:0.27147705845380266
# residual_sugar:2.5407605279698307
# chlorides:0.08749968573224387
# free_sulfur_dioxide:15.861722187303583
# total_sulfur_dioxide:46.49842866121936
# density:0.9967465304839724
# pH:3.3113576367064743
# sulphates:0.6586109365179132
# alcohol:10.42605279698303
# quality:5.637963544940289

# %%
dataset['fixed_acidity'] = dataset['fixed_acidity'].fillna(mean_fixed_acidity)
dataset['volatile_acidity'] = dataset['volatile_acidity'].fillna(mean_volatile_acidity)
dataset['citric_acid'] = dataset['citric_acid'].fillna(mean_citric_acid)
dataset['residual_sugar'] = dataset['residual_sugar'].fillna(mean_residual_sugar)
dataset['chlorides'] = dataset['chlorides'].fillna(mean_chlorides)
dataset['free_sulfur_dioxide'] = dataset['free_sulfur_dioxide'].fillna(mean_free_sulfur_dioxide)
dataset['total_sulfur_dioxide'] = dataset['total_sulfur_dioxide'].fillna(mean_total_sulfur_dioxide)
dataset['density'] = dataset['density'].fillna(mean_density)
dataset['pH'] = dataset['pH'].fillna(mean_pH)
dataset['sulphates'] = dataset['sulphates'].fillna(mean_sulphates)
dataset['alcohol'] = dataset['alcohol'].fillna(mean_alcohol)
dataset['quality'] = dataset['quality'].fillna(mean_quality)

# %%
dataset
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density        pH  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed_acidity         1601 non-null   float64
#  2   volatile_acidity      1601 non-null   float64
#  3   citric_acid           1601 non-null   float64
#  4   residual_sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free_sulfur_dioxide   1601 non-null   float64
#  7   total_sulfur_dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1601 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
dataset.drop_duplicates()
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density        pH  \
# ...

# %% [markdown]
# l first cleaned the data and removed Nan values after l had imported it into jupyter. l named it "new_dataset" to distinguish it from the original dataset. This enabled me to find the mean with no errors since there's no mean for a null input.The mean value is significant because instead of removing null values and losing some important data, we get an approximate value inplace of the null. Mode method and Median method could have been used but the Mean method is most accurate.

# %% [markdown]
# ###  Statistical inferences of entire dataset

# %%
mean_dataset = dataset.mean()
median_dataset = dataset.median()
std_dataset = dataset.std()
min_dataset = dataset.min()
max_dataset = dataset.max()

# %%
print("Mean:", mean_dataset)
print("Median:", median_dataset)
print("Standard deviation:", dataset)
print("Minimum:", min_dataset)
print("Maximum:", max_dataset)
# Out:
# Mean: ID                      801.000000
# fixed_acidity             8.319875
# volatile_acidity          0.527742
# citric_acid               0.271175
# residual_sugar            2.538445
# chlorides                 0.087488
# free_sulfur_dioxide      15.886859
# total_sulfur_dioxide     46.519987
# density                   0.996746
# pH                        3.311106
# sulphates                 0.658220
# alcohol                  10.423204
# quality                   5.636251
# dtype: float64
# Median: ID                      801.00000
# fixed_acidity             7.90000
# volatile_acidity          0.52000
# citric_acid               0.26000
# residual_sugar            2.20000
# chlorides                 0.07900
# free_sulfur_dioxide      14.00000
# total_sulfur_dioxide     38.00000
# density                   0.99675
# pH                        3.31000
# sulphates                 0.62000
# alcohol                  10.20000
# quality                   6.00000
# dtype: float64
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(dataset)

# %%
import seaborn as sb

# %%
plt.figure(figsize=(12,4), dpi= 300)
p = sb.scatterplot(data=dataset, palette='Dark2')
plt.show()

# %%
fig = plt.figure(figsize=(10,14), dpi=160)
explode = [0,0.1]
lb= ['Below', 'Above']
#4 rows 3 columns
# giving all
x= dataset['fixed_acidity'] < dataset['fixed_acidity'].mean()
#first row, first column
ax1 = plt.subplot2grid((4,3),(0,0))
plt.pie(x.value_counts(), colors=("g","r"),labels= lb, autopct = '%.2f%%', explode= explode)
plt.title('fixed_acidity')

y= dataset['volatile_acidity'] < dataset['volatile_acidity'].mean()
#first row sec column
ax2 = plt.subplot2grid((4,3),(0, 1))
plt.pie(y.value_counts(),colors=("g","r"),labels= lb, autopct = '%.2f%%', explode= explode)
plt.title('volatile_acidity')

z = dataset['citric_acid'] < dataset['citric_acid'].mean()
#first row thrird column
ax3 = plt.subplot2grid((4,3),(0, 2))
plt.pie(z.value_counts(),colors=("g","r"),labels= lb, autopct = '%.2f%%', explode= explode)
plt.title('citric_acid')

a= dataset['residual_sugar'] < dataset['residual_sugar'].mean()
#second row, first column
ax1 = plt.subplot2grid((4,3),(1,0))
plt.pie(a.value_counts(),colors=("g","r"), autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('residual_sugar')

c=dataset.chlorides<dataset.chlorides.mean()
#second row thrird column
ax1 = plt.subplot2grid((4,3), (1, 1))
plt.pie(c.value_counts() ,colors=("g","r"), autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('chlorides')

d= dataset['free_sulfur_dioxide']<dataset['free_sulfur_dioxide'].mean()
#third row, first column
ax1 = plt.subplot2grid((4,3),(1,2))
plt.pie(d.value_counts() ,colors=("g","r"), autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('free_sulfur_dioxide')

e= dataset['total_sulfur_dioxide']< dataset['total_sulfur_dioxide'].mean()
#third row sec column
ax1 = plt.subplot2grid((4,3),(2, 0))
plt.pie(e.value_counts(),colors=("g","r"),autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('total_sulfur_dioxide')

f= dataset.density < dataset.density.mean()
#third row thrird column
ax1 = plt.subplot2grid((4,3),(2, 1))
plt.pie(f.value_counts(),colors=("g","r"), autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('density')

g= dataset.pH<dataset.pH.mean()
#fourth row, first column
ax1 = plt.subplot2grid((4,3),(2,2))
plt.pie(g.value_counts(),colors=("g","r"), autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('pH')

h=dataset.sulphates<dataset.sulphates.mean()
#fourth row sec column
ax1 = plt.subplot2grid((4,3),(3,0))
plt.pie(h.value_counts(), colors=("g","r"),autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('sulphates')

i=dataset.alcohol<dataset.alcohol.mean()
#fourth row thrird column
ax1 = plt.subplot2grid((4,3),(3,1))
plt.pie(i.value_counts(),colors=("g","r"), autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('alcohol')

j=dataset.quality<dataset.quality.mean()
#fifth row, first column
ax1 = plt.subplot2grid((4,3),(3,2))
plt.pie(j.value_counts(),colors=("g","r"),autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('quality')
# Out:
# Text(0.5, 1.0, 'quality')

# %% [markdown]
# ### Statistical inferences of individual columns in dataset

# %%
fixed_acidity_mean = dataset['fixed_acidity'].mean()
fixed_acidity_median = dataset['fixed_acidity'].median()
fixed_acidity_std = dataset['fixed_acidity'].std()
fixed_acidity_min = dataset['fixed_acidity'].min()
fixed_acidity_max = dataset['fixed_acidity'].max()

# %%
print("Mean:", fixed_acidity_mean)
print("Median:", fixed_acidity_median)
print("Standard deviation:", fixed_acidity_std)
print("Minimum:", fixed_acidity_min)
print("Maximum:", fixed_acidity_max)
# Out:
# Mean: 8.319875000000001
# Median: 7.9
# Standard deviation: 1.7400387405562694
# Minimum: 4.6
# Maximum: 15.9

# %%
volatile_acidity_mean = dataset['volatile_acidity'].mean()
volatile_acidity_median = dataset['volatile_acidity'].median()
volatile_acidity_std = dataset['volatile_acidity'].std()
volatile_acidity_min = dataset['volatile_acidity'].min()
volatile_acidity_max = dataset['volatile_acidity'].max()

# %%
print("Mean:", volatile_acidity_mean)
print("Median:", volatile_acidity_median)
print("Standard deviation:", volatile_acidity_std)
print("Minimum:", volatile_acidity_min)
print("Maximum:", volatile_acidity_max)
# Out:
# Mean: 0.5277420362273579
# Median: 0.52
# Standard deviation: 0.17898116601503405
# Minimum: 0.12
# Maximum: 1.58

# %%
citric_acid_mean = dataset['citric_acid'].mean()
citric_acid_median = dataset['citric_acid'].median()
citric_acid_std = dataset['citric_acid'].std()
citric_acid_min = dataset['citric_acid'].min()
citric_acid_max = dataset['citric_acid'].max()

# %%
print("Mean:", citric_acid_mean)
print("Median:", citric_acid_median)
print("Standard deviation:", citric_acid_std)
print("Minimum:", citric_acid_min)
print("Maximum:", citric_acid_max)
# Out:
# Mean: 0.271175
# Median: 0.26
# Standard deviation: 0.19474457060432368
# Minimum: 0.0
# Maximum: 1.0

# %%
residual_sugar_mean = dataset['residual_sugar'].mean()
residual_sugar_median = dataset['residual_sugar'].median()
residual_sugar_std = dataset['residual_sugar'].std()
residual_sugar_min = dataset['residual_sugar'].min()
residual_sugar_max = dataset['residual_sugar'].max()

# %%
print("Mean:", residual_sugar_mean)
print("Median:", residual_sugar_median)
print("Standard deviation:", residual_sugar_std)
print("Minimum:", residual_sugar_min)
print("Maximum:", residual_sugar_max)
# Out:
# Mean: 2.5384447220487196
# Median: 2.2
# Standard deviation: 1.4091378630562335
# Minimum: 0.9
# Maximum: 15.5

# %%
chlorides_mean = dataset['chlorides'].mean()
chlorides_median = dataset['chlorides'].median()
chlorides_std = dataset['chlorides'].std()
chlorides_min = dataset['chlorides'].min()
chlorides_max = dataset['chlorides'].max()

# %%
print("Mean:", chlorides_mean)
print("Median:", chlorides_median)
print("Standard deviation:", chlorides_std)
print("Minimum:", chlorides_min)
print("Maximum:", chlorides_max)
# Out:
# Mean: 0.08748750721873624
# Median: 0.079
# Standard deviation: 0.047031885793927614
# Minimum: 0.012
# Maximum: 0.611

# %%
free_sulfur_dioxide_mean = dataset['free_sulfur_dioxide'].mean()
free_sulfur_dioxide_median = dataset['free_sulfur_dioxide'].median()
free_sulfur_dioxide_std = dataset['free_sulfur_dioxide'].std()
free_sulfur_dioxide_min = dataset['free_sulfur_dioxide'].min()
free_sulfur_dioxide_max = dataset['free_sulfur_dioxide'].max()

# %%
print("Mean:", free_sulfur_dioxide_mean)
print("Median:", free_sulfur_dioxide_median)
print("Standard deviation:", free_sulfur_dioxide_std)
print("Minimum:", free_sulfur_dioxide_min)
print("Maximum:", free_sulfur_dioxide_max)
# Out:
# Mean: 15.886859289311245
# Median: 14.0
# Standard deviation: 10.4552177466346
# Minimum: 1.0
# Maximum: 72.0

# %%
total_sulfur_dioxide_mean = dataset['total_sulfur_dioxide'].mean()
total_sulfur_dioxide_median = dataset['total_sulfur_dioxide'].median()
total_sulfur_dioxide_std = dataset['total_sulfur_dioxide'].std()
total_sulfur_dioxide_min = dataset['total_sulfur_dioxide'].min()
total_sulfur_dioxide_max = dataset['total_sulfur_dioxide'].max()

# %%
print("Mean:", total_sulfur_dioxide_mean)
print("Median:", total_sulfur_dioxide_median)
print("Standard deviation:", total_sulfur_dioxide_std)
print("Minimum:", total_sulfur_dioxide_min)
print("Maximum:", total_sulfur_dioxide_max)
# Out:
# Mean: 46.5199865263343
# Median: 38.0
# Standard deviation: 32.9674163044459
# Minimum: 6.0
# Maximum: 289.0

# %%
density_mean = dataset['density'].mean()
density_median = dataset['density'].median()
density_std = dataset['density'].std()
density_min = dataset['density'].min()
density_max = dataset['density'].max()

# %%
print("Mean:", density_mean)
print("Median:", density_median)
print("Standard deviation:", density_std)
print("Minimum:", density_min)
print("Maximum:", density_max)
# Out:
# Mean: 0.9967456443038627
# Median: 0.99675
# Standard deviation: 0.0018866714965984563
# Minimum: 0.99007
# Maximum: 1.00369

# %%
pH_mean = dataset['pH'].mean()
pH_median = dataset['pH'].median()
pH_std = dataset['pH'].std()
pH_min = dataset['pH'].min()
pH_max = dataset['pH'].max()

# %%
print("Mean:", pH_mean)
print("Median:", pH_median)
print("Standard deviation:", pH_std)
print("Minimum:", pH_min)
print("Maximum:", pH_max)
# Out:
# Mean: 3.3111064070185554
# Median: 3.31
# Standard deviation: 0.1542901933060228
# Minimum: 2.74
# Maximum: 4.01

# %%
sulphates_mean = dataset['sulphates'].mean()
sulphates_median = dataset['sulphates'].median()
sulphates_std = dataset['sulphates'].std()
sulphates_min = dataset['sulphates'].min()
sulphates_max = dataset['sulphates'].max()

# %%
print("Mean:", sulphates_mean)
print("Median:", sulphates_median)
print("Standard deviation:", sulphates_std)
print("Minimum:", sulphates_min)
print("Maximum:", sulphates_max)
# Out:
# Mean: 0.6582198625858838
# Median: 0.62
# Standard deviation: 0.16947054797288755
# Minimum: 0.33
# Maximum: 2.0

# %%
alcohol_mean = dataset['alcohol'].mean()
alcohol_median = dataset['alcohol'].median()
alcohol_std = dataset['alcohol'].std()
alcohol_min = dataset['alcohol'].min()
alcohol_max = dataset['alcohol'].max()

# %%
print("Mean:", alcohol_mean)
print("Median:", alcohol_median)
print("Standard deviation:", alcohol_std)
print("Minimum:", alcohol_min)
print("Maximum:", alcohol_max)
# Out:
# Mean: 10.42320424734541
# Median: 10.2
# Standard deviation: 1.0654949345575446
# Minimum: 8.4
# Maximum: 14.9

# %%
quality_mean = dataset['quality'].mean()
quality_median = dataset['quality'].median()
quality_std = dataset['quality'].std()
quality_min = dataset['quality'].min()
quality_max = dataset['quality'].max()

# %%
print("Mean:",quality_mean)
print("Median:",quality_median)
print("Standard deviation:", quality_std)
print("Minimum:", quality_min)
print("Maximum:", quality_max)
# Out:
# Mean: 5.636251070296653
# Median: 6.0
# Standard deviation: 0.807115815316492
# Minimum: 3.0
# Maximum: 8.0

# %% [markdown]
# ### Some hidden inferences

# %%
dataset.head()
# Out:
#    ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0   1            7.4              0.70         0.00             1.9
# 1   2            7.8              0.88         0.00             2.6
# 2   3            7.8              0.76         0.04             2.3
# 3   4           11.2              0.28         0.56             1.9
# 4   5            7.4              0.70         0.00             1.9
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density        pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.510000
# 1      0.098                 25.0                  67.0   0.9968  3.200000
# 2      0.092                 15.0                  54.0   0.9970  3.311358
# 3      0.075                 17.0                  60.0   0.9980  3.160000
# 4      0.076                 11.0                  34.0   0.9978  3.510000
#
#    sulphates  alcohol  quality
# 0       0.56      9.4      5.0
# 1       0.68      9.8      5.0
# ...

# %% [markdown]
# We are testing for the quality of beverages and 'Quality' is the dependent variable. It depends on the 'fixed acidity' and 'volatile acidity',the remaining variables are the independent variables and since they are all numerical variables that are on the ratio scale inference of the data can be a multiple regression model because there are multiple response variables to pair the significance of each variable on the quality of the beverage

# %%
dataset.describe()
# Out:
#                 ID  fixed_acidity  volatile_acidity  citric_acid  \
# count  1601.000000    1600.000000       1601.000000  1600.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.740039          0.178981     0.194745
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual_sugar    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# count     1601.000000  1598.000000          1600.000000           1600.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047076            10.458487             32.977723
# ...

# %%
dataset.corr()
# Out:
#                             ID  fixed_acidity  volatile_acidity  citric_acid  \
# ID                    1.000000      -0.268147         -0.009544    -0.153429
# fixed_acidity        -0.268147       1.000000         -0.255570     0.671061
# volatile_acidity     -0.009544      -0.255570          1.000000    -0.552917
# citric_acid          -0.153429       0.671061         -0.552917     1.000000
# residual_sugar       -0.031589       0.114601          0.001877     0.143518
# chlorides            -0.119363       0.093544          0.060826     0.204054
# free_sulfur_dioxide   0.091197      -0.153049         -0.010592    -0.061269
# total_sulfur_dioxide -0.113913      -0.113356          0.076249     0.036030
# density              -0.368825       0.667912          0.022771     0.364309
# pH                    0.135208      -0.682644          0.235306    -0.543019
# sulphates            -0.124243       0.182303         -0.261364     0.312895
# ...

# %%
data_corr = dataset.corr()

# %%
plt.figure(figsize=(10,10))
sb.heatmap(data_corr, annot=True, cmap='BuPu', cbar=True)
# Out:
# <Axes: >
